# %%
## read demographic data and freesurfer outputs
from pathlib import Path
import nipype.interfaces.io as nio
import pandas as pd
#reading freesurfer results
out_dir = Path("/output")
fig_dir = out_dir / "figs"
fsdata_file = out_dir / 'freesurfer_out_preped.csv'
tab_data = pd.read_csv(fsdata_file, sep=',', header=0, index_col=0);
# distribution of large brain parts ratio
def lr_ratio(data, items_basic, items_single, items_lr):
    item_left   = [ "Left_"+x  for x in items_lr];
    item_right  = [ "Right_"+x for x in items_lr];
    items_all = items_single + item_left + item_right + items_lr;
    tmp_data = data[items_basic+items_single+item_left+item_right];
    for x in items_lr:
        tmp_data[x]  = tmp_data["Left_"+x] + tmp_data["Right_"+x]
    #for x in items_all:
    #    tmp_data[x+"_r"] = tmp_data[x]/tmp_data["eTIV"]  
    return tmp_data, items_basic+items_all
tab_data=tab_data.drop(index='sub_0064');
drop_col_list = ['Left_WM_hypointensities', 'Right_WM_hypointensities', '5th_Ventricle'];
tab_data=tab_data.drop(columns=drop_col_list);
# Out:
# 201203-20:26:29,217 nipype.utils WARNING:
# 	 A newer version (1.5.1) of nipy/nipype is available. You are using 1.5.0

# %%
def rm_age_sex(data, var_list):
    from sklearn import linear_model
    import numpy as np
    dat = data.copy()
    nc_data = dat[dat["is_NC"] == 1]
    x_nc = np.array([np.ones(nc_data.shape[0]), np.array((nc_data["is_Male"])), np.array((nc_data["age"]))]).T; 
    x_all= np.array([np.ones(dat.shape[0]), np.array((dat["is_Male"])), np.array((dat["age"]))]).T;
    reg_list = []; new_col=[];
    for x in var_list:
        reg = linear_model.LinearRegression()
        y_nc= np.array(nc_data[x]);
        reg.fit(x_nc, y_nc);
        tmp_col = x+"_AgeSexRemoved"
        dat[tmp_col] = dat[x]-np.matmul(x_all[:,1:], reg.coef_[1:])
        dat[tmp_col+"_resid"] = dat[x]-reg.predict(x_all)
        dat[tmp_col+"_resid_per"] = (dat[x]-reg.predict(x_all))/dat[x]
        reg_list.append(reg); new_col.append(tmp_col);
    return dat, new_col, reg_list   
# plot distribution of brian tissues
def screen_Tukeyhsd(data, test_list):
    import statsmodels.stats.multicomp as mc
    from functools import reduce
    res_all=[]; reject_index=[];
    for i in range(len(test_list)):
        x = test_list[i];
        #print(x)
        tmp_comp = mc.MultiComparison(data[x], data['diagnosis'])
        tmp_res = tmp_comp.tukeyhsd()
        res_all.append(tmp_res.summary())
        if sum(list(tmp_res.reject))>2:
            reject_index.append(i)
            print(str(i)+"th Tukey HSD test positive -->> "+x)
            print(res_all[i])
            #print(res_all[i])
    return res_all, reject_index

# %%
# select the data
from sklearn import linear_model
import numpy as np
items_basic = ["diagnosis", "age", "sex", "is_PD", "is_ET","is_NC",
               "is_Male", "is_Female", "eTIV", "TotalGrayVol",];
items_single = ["CerebralWhiteMatterVol", "CortexVol", "Brain_Stem", "SubCortGrayVol", "CSF", 
                "3rd_Ventricle", "4th_Ventricle", "SupraTentorialVol", 
                "CC_Anterior", "CC_Central", "CC_Mid_Anterior", "CC_Mid_Posterior", "CC_Posterior"];
items_lr  = ["Inf_Lat_Vent", "Lateral_Ventricle", 
             "Cerebellum_Cortex", "Cerebellum_White_Matter",
             "Accumbens_area", "Amygdala", "Hippocampus", 
             "Pallidum", "Caudate", "Putamen", "Thalamus_Proper"];
all_data, items_all = lr_ratio(tab_data, items_basic, items_single, items_lr);
rm_AgeSex_list = items_all[8:];

new_data=all_data[all_data["age"]>=60];
stf_data=new_data[new_data["age"]<=69];

all_as_data, rm_as_col_list, rm_as_reg_list = rm_age_sex(all_data, rm_AgeSex_list);
stf_as_data, rm_as_col_list, rm_as_reg_list = rm_age_sex(stf_data, rm_AgeSex_list);

# Check regression residuals
resid_list = [x+"_resid_per" for x in rm_as_col_list ];
#rm_as_data[resid_list].plot.box(vert=False,figsize=(10,20))
# Out:
# /usr/local/miniconda/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# age and sex distribution
import seaborn as sns
GROUPS  = ['PD','ET','NC']
print("60-70: ")
[print(x, ': ', len(stf_as_data[stf_as_data["diagnosis"]==x])) for x in GROUPS]
print("all: ")
[print(x, ': ', len(all_as_data[all_sa_data["diagnosis"]==x])) for x in GROUPS]

sns.set_theme(style="darkgrid")
sns.displot(
    all_as_data, x="age", col="diagnosis", row="sex",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True))
sns.displot(
    stf_as_data, x="age", col="diagnosis", row="sex",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True))
# Out:
# 60-70:
# PD :  17
# ET :  5
# NC :  7
# all:
# PD :  40
# ET :  29
# NC :  32

# %%
def norm_by_feature(data, item_list, norm_item):
    t_data = data.copy();
    new_items=[];
    for x in item_list:
        new_col = x+"_r";
        t_data[new_col] = t_data[x]/t_data[norm_item];
        new_items.append(new_col)
    return t_data, new_items 
norm_item = 'eTIV_AgeSexRemoved';

all_asr_data, rm_asr_items = norm_by_feature(all_as_data, rm_as_col_list[1:]+rm_AgeSex_list[:], norm_item)
stf_asr_data, rm_asr_items = norm_by_feature(stf_as_data, rm_as_col_list[1:]+rm_AgeSex_list[:], norm_item)

# %%
non_feature_list = ["diagnosis", "age", "sex", "is_PD", "is_ET","is_NC", "is_Male", "is_Female"];
# all_asr_data, all_as_data, all_data
x_all_data = all_asr_data;
x_stf_data = stf_asr_data;
print("Screening all data(asr):")
res_all, reject_asr_index_all = screen_Tukeyhsd(all_asr_data, all_asr_data.columns.drop(non_feature_list))
print('All data Discovered diff: ',len(reject_asr_index_all))
print('Diff features: ',all_asr_data.columns.drop(non_feature_list)[reject_asr_index_all])
print("Screening 60-70 data(asr):")
res_stf, reject_asr_index_stf = screen_Tukeyhsd(stf_asr_data, stf_asr_data.columns.drop(non_feature_list))
print('60-70 Discovered diff: ',len(reject_asr_index_stf))
print('Diff features: ',stf_asr_data.columns.drop(non_feature_list)[reject_asr_index_stf])

#raw data
print("Screening all data raw:")
res_all, reject_index_all = screen_Tukeyhsd(all_data, all_data.columns.drop(non_feature_list))
print('All data Discovered diff: ',len(reject_index_all))
print('Diff features: ',all_data.columns.drop(non_feature_list)[reject_index_all])
print("Screening 60-70 data raw:")
res_stf, reject_index_stf = screen_Tukeyhsd(stf_data, stf_data.columns.drop(non_feature_list))
print('60-70 Discovered diff: ',len(reject_index_stf))
print('Diff features: ',stf_data.columns.drop(non_feature_list)[reject_index_stf])
# Out:
# Screening all data(asr):
# 1th Tukey HSD test positive -->> TotalGrayVol
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
# group1 group2   meandiff  p-adj     lower      upper    reject
# --------------------------------------------------------------
#     ET     NC  55993.1675  0.001  21514.6042 90471.7308   True
#     ET     PD  39891.0446 0.0129   7092.5597 72689.5295   True
#     NC     PD -16102.1229 0.4569 -47996.8944 15792.6486  False
# --------------------------------------------------------------
# 3th Tukey HSD test positive -->> CortexVol
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
# group1 group2   meandiff  p-adj     lower      upper    reject
# --------------------------------------------------------------
#     ET     NC  51884.8173  0.001   23145.458 80624.1766   True
#     ET     PD  36111.6007 0.0062   8772.6586 63450.5427   True
#     NC     PD -15773.2166 0.3394 -42358.8748 10812.4415  False
# --------------------------------------------------------------
# 6th Tukey HSD test positive -->> CSF
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#     ET     NC -242.8114 0.0019  -407.341 -78.2819   True
#     ET     PD -209.9302 0.0053 -366.4425 -53.4179   True
#     NC     PD   32.8812 0.8502 -119.3186 185.0811  False
# --------------------------------------------------------
# 7th Tukey HSD test positive -->> 3rd_Ventricle
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
# group1 group2  meandiff p-adj    lower      upper   reject
# ----------------------------------------------------------
#     ET     NC -722.6526  0.001 -1115.1316 -330.1736   True
#     ET     PD -654.6801  0.001 -1028.0343 -281.3259   True
#     NC     PD   67.9725 0.8893  -295.0945  431.0395  False
# ----------------------------------------------------------
# 15th Tukey HSD test positive -->> Left_Inf_Lat_Vent
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
# group1 group2  meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------
#     ET     NC -328.8655 0.0015 -547.0167 -110.7143   True
#     ET     PD  -270.678  0.007 -478.1991  -63.1569   True
#     NC     PD   58.1875 0.7522 -143.6156  259.9906  False
# ---------------------------------------------------------
# 16th Tukey HSD test positive -->> Left_Lateral_Ventricle
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================
# group1 group2  meandiff  p-adj     lower      upper    reject
# -------------------------------------------------------------
#     ET     NC -8329.3114  0.001 -13415.6847 -3242.9382   True
#     ET     PD -6481.2377 0.0054 -11319.7611 -1642.7142   True
#     NC     PD  1848.0737 0.6105  -2857.1314  6553.2789  False
# -------------------------------------------------------------
# 20th Tukey HSD test positive -->> Left_Amygdala
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#     ET     NC 182.1445  0.007    42.364  321.925   True
#     ET     PD 136.8464 0.0422    3.8771 269.8157   True
#     NC     PD -45.2981 0.6681 -174.6036  84.0074  False
# -------------------------------------------------------
# 26th Tukey HSD test positive -->> Right_Inf_Lat_Vent
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj   lower     upper   reject
# --------------------------------------------------------
#     ET     NC -442.6864 0.001 -676.4303 -208.9426   True
#     ET     PD -424.6502 0.001 -647.0041 -202.2962   True
#     NC     PD   18.0363   0.9 -198.1911  234.2636  False
# --------------------------------------------------------
# 27th Tukey HSD test positive -->> Right_Lateral_Ventricle
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================
# group1 group2  meandiff  p-adj     lower      upper    reject
# -------------------------------------------------------------
#     ET     NC -7257.9531  0.001 -11596.0841 -2919.8221   True
#     ET     PD  -5280.335 0.0083  -9407.0767 -1153.5933   True
#     NC     PD  1977.6181 0.4739  -2035.4173  5990.6536  False
# -------------------------------------------------------------
# 37th Tukey HSD test positive -->> Inf_Lat_Vent
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
# group1 group2  meandiff p-adj    lower      upper   reject
# ----------------------------------------------------------
#     ET     NC -771.5519  0.001 -1199.9794 -343.1244   True
#     ET     PD -695.3282  0.001 -1102.8792 -287.7772   True
#     NC     PD   76.2238 0.8824  -320.0978  472.5453  False
# ----------------------------------------------------------
# 38th Tukey HSD test positive -->> Lateral_Ventricle
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
# group1 group2   meandiff  p-adj     lower      upper    reject
# --------------------------------------------------------------
#     ET     NC -15587.2645  0.001 -24846.2462 -6328.2829   True
#     ET     PD -11761.5727 0.0056 -20569.3808 -2953.7646   True
#     NC     PD   3825.6919 0.5375  -4739.4302 12390.8139  False
# --------------------------------------------------------------
# 57th Tukey HSD test positive -->> CortexVol_AgeSexRemoved
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
# group1 group2   meandiff  p-adj     lower      upper    reject
# --------------------------------------------------------------
#     ET     NC   39605.889 0.0016  13177.7866 66033.9914   True
#     ET     PD  28627.4913 0.0215   3487.1829 53767.7998   True
#     NC     PD -10978.3976 0.5342 -35426.0023  13469.207  False
# --------------------------------------------------------------
# 58th Tukey HSD test positive -->> CortexVol_AgeSexRemoved_resid
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
# group1 group2   meandiff  p-adj     lower      upper    reject
# --------------------------------------------------------------
#     ET     NC   39605.889 0.0016  13177.7866 66033.9914   True
#     ET     PD  28627.4913 0.0215   3487.1829 53767.7998   True
#     NC     PD -10978.3976 0.5342 -35426.0023  13469.207  False
# --------------------------------------------------------------
# 59th Tukey HSD test positive -->> CortexVol_AgeSexRemoved_resid_per
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0972  0.001   0.036 0.1584   True
#     ET     PD    0.066 0.0221  0.0078 0.1242   True
#     NC     PD  -0.0312 0.3935 -0.0878 0.0254  False
# ---------------------------------------------------
# 66th Tukey HSD test positive -->> CSF_AgeSexRemoved
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#     ET     NC -251.1164  0.001 -410.9128 -91.3201   True
#     ET     PD -204.4385 0.0052 -356.4483 -52.4287   True
#     NC     PD    46.678  0.715 -101.1434 194.4994  False
# --------------------------------------------------------
# 67th Tukey HSD test positive -->> CSF_AgeSexRemoved_resid
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#     ET     NC -251.1164  0.001 -410.9128 -91.3201   True
#     ET     PD -204.4385 0.0052 -356.4483 -52.4287   True
#     NC     PD    46.678  0.715 -101.1434 194.4994  False
# --------------------------------------------------------
# 68th Tukey HSD test positive -->> CSF_AgeSexRemoved_resid_per
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     ET     NC  -0.1612 0.0041 -0.2782 -0.0442   True
#     ET     PD  -0.1461 0.0066 -0.2574 -0.0348   True
#     NC     PD   0.0152    0.9 -0.0931  0.1234  False
# ----------------------------------------------------
# 69th Tukey HSD test positive -->> 3rd_Ventricle_AgeSexRemoved
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#     ET     NC -410.4672 0.0121 -745.5106 -75.4238   True
#     ET     PD -396.6332 0.0106 -715.3505 -77.9159   True
#     NC     PD    13.834    0.9 -296.1016 323.7695  False
# --------------------------------------------------------
# 70th Tukey HSD test positive -->> 3rd_Ventricle_AgeSexRemoved_resid
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#     ET     NC -410.4672 0.0121 -745.5106 -75.4238   True
#     ET     PD -396.6332 0.0106 -715.3505 -77.9159   True
#     NC     PD    13.834    0.9 -296.1016 323.7695  False
# --------------------------------------------------------
# 71th Tukey HSD test positive -->> 3rd_Ventricle_AgeSexRemoved_resid_per
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     ET     NC  -0.2226 0.0472 -0.4431 -0.0022   True
#     ET     PD   -0.221 0.0365 -0.4307 -0.0112   True
#     NC     PD   0.0017    0.9 -0.2023  0.2056  False
# ----------------------------------------------------
# 126th Tukey HSD test positive -->> Right_Inf_Lat_Vent_AgeSexRemoved
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj   lower     upper   reject
# --------------------------------------------------------
#     ET     NC -355.9871 0.001 -571.7033  -140.271   True
#     ET     PD -348.1071 0.001 -553.3118 -142.9025   True
#     NC     PD      7.88   0.9 -191.6706  207.4305  False
# --------------------------------------------------------
# 127th Tukey HSD test positive -->> Right_Inf_Lat_Vent_AgeSexRemoved_resid
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj   lower     upper   reject
# --------------------------------------------------------
#     ET     NC -355.9871 0.001 -571.7033  -140.271   True
#     ET     PD -348.1071 0.001 -553.3118 -142.9025   True
#     NC     PD      7.88   0.9 -191.6706  207.4305  False
# --------------------------------------------------------
# 128th Tukey HSD test positive -->> Right_Inf_Lat_Vent_AgeSexRemoved_resid_per
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     ET     NC  -0.3118 0.0169  -0.577 -0.0465   True
#     ET     PD  -0.2914 0.0194 -0.5437 -0.0391   True
#     NC     PD   0.0204    0.9  -0.225  0.2658  False
# ----------------------------------------------------
# 147th Tukey HSD test positive -->> Right_Pallidum_AgeSexRemoved
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#     ET     NC 215.7582  0.004    59.575 371.9414   True
#     ET     PD 172.2764 0.0188   23.7037 320.8491   True
#     NC     PD -43.4818 0.7351 -187.9608 100.9972  False
# -------------------------------------------------------
# 148th Tukey HSD test positive -->> Right_Pallidum_AgeSexRemoved_resid
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#     ET     NC 215.7582  0.004    59.575 371.9414   True
#     ET     PD 172.2764 0.0188   23.7037 320.8491   True
#     NC     PD -43.4818 0.7351 -187.9608 100.9972  False
# -------------------------------------------------------
# 149th Tukey HSD test positive -->> Right_Pallidum_AgeSexRemoved_resid_per
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC    0.111 0.0039  0.0309 0.1911   True
#     ET     PD   0.0817 0.0327  0.0054 0.1579   True
#     NC     PD  -0.0293 0.6065 -0.1035 0.0448  False
# ---------------------------------------------------
# 159th Tukey HSD test positive -->> Inf_Lat_Vent_AgeSexRemoved
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
# group1 group2  meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------
#     ET     NC -562.0702 0.0023 -948.0672 -176.0732   True
#     ET     PD -514.6393 0.0034 -881.8273 -147.4512   True
#     NC     PD    47.431    0.9 -309.6398  404.5017  False
# ---------------------------------------------------------
# 160th Tukey HSD test positive -->> Inf_Lat_Vent_AgeSexRemoved_resid
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
# group1 group2  meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------
#     ET     NC -562.0702 0.0023 -948.0672 -176.0732   True
#     ET     PD -514.6393 0.0034 -881.8273 -147.4512   True
#     NC     PD    47.431    0.9 -309.6398  404.5017  False
# ---------------------------------------------------------
# 192th Tukey HSD test positive -->> TotalGrayVol_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0347  0.001   0.018 0.0514   True
#     ET     PD   0.0317  0.001  0.0158 0.0476   True
#     NC     PD   -0.003 0.8782 -0.0185 0.0124  False
# ---------------------------------------------------
# 194th Tukey HSD test positive -->> CortexVol_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0336  0.001  0.0196 0.0476   True
#     ET     PD   0.0281  0.001  0.0148 0.0415   True
#     NC     PD  -0.0055 0.5702 -0.0185 0.0075  False
# ---------------------------------------------------
# 197th Tukey HSD test positive -->> CSF_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     ET     NC  -0.0001  0.001 -0.0002 -0.0001   True
#     ET     PD  -0.0001 0.0088 -0.0002    -0.0   True
#     NC     PD      0.0 0.5821    -0.0  0.0001  False
# ----------------------------------------------------
# 198th Tukey HSD test positive -->> 3rd_Ventricle_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC  -0.0003 0.0151 -0.0005   -0.0   True
#     ET     PD  -0.0003 0.0133 -0.0005   -0.0   True
#     NC     PD      0.0    0.9 -0.0002 0.0002  False
# ---------------------------------------------------
# 200th Tukey HSD test positive -->> SupraTentorialVol_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0394  0.001  0.0199  0.059   True
#     ET     PD   0.0351  0.001  0.0165 0.0537   True
#     NC     PD  -0.0044 0.8154 -0.0224 0.0137  False
# ---------------------------------------------------
# 217th Tukey HSD test positive -->> Right_Inf_Lat_Vent_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#     ET     NC  -0.0002 0.001 -0.0004 -0.0001   True
#     ET     PD  -0.0002 0.001 -0.0004 -0.0001   True
#     NC     PD      0.0   0.9 -0.0001  0.0001  False
# ---------------------------------------------------
# 223th Tukey HSD test positive -->> Right_Hippocampus_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0003 0.0013  0.0001 0.0004   True
#     ET     PD   0.0002  0.031     0.0 0.0003   True
#     NC     PD  -0.0001 0.4054 -0.0002 0.0001  False
# ---------------------------------------------------
# 224th Tukey HSD test positive -->> Right_Pallidum_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0002  0.001  0.0001 0.0003   True
#     ET     PD   0.0001  0.001  0.0001 0.0002   True
#     NC     PD     -0.0 0.7706 -0.0001 0.0001  False
# ---------------------------------------------------
# 228th Tukey HSD test positive -->> Inf_Lat_Vent_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     ET     NC  -0.0004  0.003 -0.0006 -0.0001   True
#     ET     PD  -0.0003 0.0041 -0.0006 -0.0001   True
#     NC     PD      0.0    0.9 -0.0002  0.0003  False
# ----------------------------------------------------
# 234th Tukey HSD test positive -->> Hippocampus_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0005  0.001  0.0002 0.0008   True
#     ET     PD   0.0003 0.0403     0.0 0.0006   True
#     NC     PD  -0.0002 0.2712 -0.0005 0.0001  False
# ---------------------------------------------------
# 235th Tukey HSD test positive -->> Pallidum_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0002 0.0025  0.0001 0.0004   True
#     ET     PD   0.0002 0.0012  0.0001 0.0004   True
#     NC     PD      0.0    0.9 -0.0001 0.0002  False
# ---------------------------------------------------
# 240th Tukey HSD test positive -->> TotalGrayVol_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0459  0.001  0.0257 0.0662   True
#     ET     PD   0.0377  0.001  0.0185 0.0569   True
#     NC     PD  -0.0082 0.5465 -0.0269 0.0105  False
# ---------------------------------------------------
# 242th Tukey HSD test positive -->> CortexVol_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     ET     NC   0.0411 0.001 0.0249 0.0574   True
#     ET     PD   0.0322 0.001 0.0167 0.0477   True
#     NC     PD  -0.0089 0.338 -0.024 0.0061  False
# -------------------------------------------------
# 245th Tukey HSD test positive -->> CSF_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC  -0.0001  0.002 -0.0002   -0.0   True
#     ET     PD  -0.0001 0.0089 -0.0002   -0.0   True
#     NC     PD      0.0 0.7544 -0.0001 0.0001  False
# ---------------------------------------------------
# 246th Tukey HSD test positive -->> 3rd_Ventricle_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#     ET     NC  -0.0005 0.001 -0.0007 -0.0002   True
#     ET     PD  -0.0004 0.001 -0.0006 -0.0002   True
#     NC     PD      0.0 0.842 -0.0002  0.0003  False
# ---------------------------------------------------
# 248th Tukey HSD test positive -->> SupraTentorialVol_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0464  0.001  0.0192 0.0736   True
#     ET     PD   0.0362 0.0035  0.0103 0.0621   True
#     NC     PD  -0.0102 0.5926 -0.0354  0.015  False
# ---------------------------------------------------
# 254th Tukey HSD test positive -->> Left_Inf_Lat_Vent_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     ET     NC  -0.0002 0.0017 -0.0003 -0.0001   True
#     ET     PD  -0.0002 0.0069 -0.0003    -0.0   True
#     NC     PD      0.0 0.7796 -0.0001  0.0002  False
# ----------------------------------------------------
# 255th Tukey HSD test positive -->> Left_Lateral_Ventricle_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     ET     NC  -0.0053  0.001 -0.0084 -0.0022   True
#     ET     PD  -0.0041 0.0043 -0.0071 -0.0011   True
#     NC     PD   0.0012 0.5784 -0.0017  0.0041  False
# ----------------------------------------------------
# 259th Tukey HSD test positive -->> Left_Amygdala_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0001 0.0015     0.0 0.0002   True
#     ET     PD   0.0001 0.0068     0.0 0.0002   True
#     NC     PD     -0.0 0.7616 -0.0001 0.0001  False
# ---------------------------------------------------
# 264th Tukey HSD test positive -->> Left_Thalamus_Proper_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#     ET     NC   0.0003 0.013  0.0001 0.0006   True
#     ET     PD   0.0003 0.007  0.0001 0.0006   True
#     NC     PD      0.0   0.9 -0.0002 0.0003  False
# --------------------------------------------------
# 265th Tukey HSD test positive -->> Right_Inf_Lat_Vent_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#     ET     NC  -0.0003 0.001 -0.0004 -0.0001   True
#     ET     PD  -0.0003 0.001 -0.0004 -0.0001   True
#     NC     PD      0.0   0.9 -0.0001  0.0002  False
# ---------------------------------------------------
# 266th Tukey HSD test positive -->> Right_Lateral_Ventricle_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     ET     NC  -0.0046  0.001 -0.0073 -0.0019   True
#     ET     PD  -0.0033 0.0091 -0.0059 -0.0007   True
#     NC     PD   0.0013  0.437 -0.0012  0.0038  False
# ----------------------------------------------------
# 271th Tukey HSD test positive -->> Right_Hippocampus_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0003  0.001  0.0001 0.0005   True
#     ET     PD   0.0002 0.0191     0.0 0.0004   True
#     NC     PD  -0.0001 0.2051 -0.0003    0.0  False
# ---------------------------------------------------
# 272th Tukey HSD test positive -->> Right_Pallidum_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0001 0.0091     0.0 0.0002   True
#     ET     PD   0.0001 0.0166     0.0 0.0002   True
#     NC     PD     -0.0    0.9 -0.0001 0.0001  False
# ---------------------------------------------------
# 275th Tukey HSD test positive -->> Right_Thalamus_Proper_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0003 0.0238     0.0 0.0006   True
#     ET     PD   0.0003 0.0127  0.0001 0.0006   True
#     NC     PD      0.0    0.9 -0.0002 0.0003  False
# ---------------------------------------------------
# 276th Tukey HSD test positive -->> Inf_Lat_Vent_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     ET     NC  -0.0005  0.001 -0.0008 -0.0002   True
#     ET     PD  -0.0004  0.001 -0.0007 -0.0002   True
#     NC     PD      0.0 0.8738 -0.0002  0.0003  False
# ----------------------------------------------------
# 277th Tukey HSD test positive -->> Lateral_Ventricle_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     ET     NC  -0.0099  0.001 -0.0157 -0.0041   True
#     ET     PD  -0.0074 0.0051 -0.0129 -0.0019   True
#     NC     PD   0.0025 0.5007 -0.0028  0.0078  False
# ----------------------------------------------------
# 281th Tukey HSD test positive -->> Amygdala_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0002 0.0095     0.0 0.0004   True
#     ET     PD   0.0002 0.0197     0.0 0.0004   True
#     NC     PD     -0.0    0.9 -0.0002 0.0001  False
# ---------------------------------------------------
# 282th Tukey HSD test positive -->> Hippocampus_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0006  0.001  0.0003  0.001   True
#     ET     PD   0.0004  0.026     0.0 0.0007   True
#     NC     PD  -0.0003 0.1382 -0.0006 0.0001  False
# ---------------------------------------------------
# 283th Tukey HSD test positive -->> Pallidum_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0002  0.017     0.0 0.0004   True
#     ET     PD   0.0002 0.0104     0.0 0.0004   True
#     NC     PD      0.0    0.9 -0.0002 0.0002  False
# ---------------------------------------------------
# 286th Tukey HSD test positive -->> Thalamus_Proper_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     ET     NC   0.0006 0.0141  0.0001 0.0012   True
#     ET     PD   0.0006 0.0073  0.0001 0.0011   True
#     NC     PD      0.0    0.9 -0.0005 0.0005  False
# ---------------------------------------------------
# All data Discovered diff:  59
# Diff features:  Index(['TotalGrayVol', 'CortexVol', 'CSF', '3rd_Ventricle',
#        'Left_Inf_Lat_Vent', 'Left_Lateral_Ventricle', 'Left_Amygdala',
#        'Right_Inf_Lat_Vent', 'Right_Lateral_Ventricle', 'Inf_Lat_Vent',
#        'Lateral_Ventricle', 'CortexVol_AgeSexRemoved',
#        'CortexVol_AgeSexRemoved_resid', 'CortexVol_AgeSexRemoved_resid_per',
#        'CSF_AgeSexRemoved', 'CSF_AgeSexRemoved_resid',
#        'CSF_AgeSexRemoved_resid_per', '3rd_Ventricle_AgeSexRemoved',
#        '3rd_Ventricle_AgeSexRemoved_resid',
#        '3rd_Ventricle_AgeSexRemoved_resid_per',
#        'Right_Inf_Lat_Vent_AgeSexRemoved',
#        'Right_Inf_Lat_Vent_AgeSexRemoved_resid',
#        'Right_Inf_Lat_Vent_AgeSexRemoved_resid_per',
#        'Right_Pallidum_AgeSexRemoved', 'Right_Pallidum_AgeSexRemoved_resid',
#        'Right_Pallidum_AgeSexRemoved_resid_per', 'Inf_Lat_Vent_AgeSexRemoved',
#        'Inf_Lat_Vent_AgeSexRemoved_resid', 'TotalGrayVol_AgeSexRemoved_r',
#        'CortexVol_AgeSexRemoved_r', 'CSF_AgeSexRemoved_r',
#        '3rd_Ventricle_AgeSexRemoved_r', 'SupraTentorialVol_AgeSexRemoved_r',
#        'Right_Inf_Lat_Vent_AgeSexRemoved_r',
#        'Right_Hippocampus_AgeSexRemoved_r', 'Right_Pallidum_AgeSexRemoved_r',
#        'Inf_Lat_Vent_AgeSexRemoved_r', 'Hippocampus_AgeSexRemoved_r',
#        'Pallidum_AgeSexRemoved_r', 'TotalGrayVol_r', 'CortexVol_r', 'CSF_r',
#        '3rd_Ventricle_r', 'SupraTentorialVol_r', 'Left_Inf_Lat_Vent_r',
#        'Left_Lateral_Ventricle_r', 'Left_Amygdala_r', 'Left_Thalamus_Proper_r',
#        'Right_Inf_Lat_Vent_r', 'Right_Lateral_Ventricle_r',
#        'Right_Hippocampus_r', 'Right_Pallidum_r', 'Right_Thalamus_Proper_r',
#        'Inf_Lat_Vent_r', 'Lateral_Ventricle_r', 'Amygdala_r', 'Hippocampus_r',
#        'Pallidum_r', 'Thalamus_Proper_r'],
#       dtype='object')
# Screening 60-70 data(asr):
# 221th Tukey HSD test positive -->> Right_Accumbens_area_AgeSexRemoved_r
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj   lower  upper reject
# --------------------------------------------------
#     ET     NC     -0.0 0.0477 -0.0001  -0.0   True
#     ET     PD  -0.0001  0.001 -0.0001  -0.0   True
#     NC     PD     -0.0 0.1753    -0.0   0.0  False
# --------------------------------------------------
# 60-70 Discovered diff:  1
# Diff features:  Index(['Right_Accumbens_area_AgeSexRemoved_r'], dtype='object')
# Screening all data raw:
# 1th Tukey HSD test positive -->> TotalGrayVol
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
# group1 group2   meandiff  p-adj     lower      upper    reject
# --------------------------------------------------------------
#     ET     NC  55993.1675  0.001  21514.6042 90471.7308   True
#     ET     PD  39891.0446 0.0129   7092.5597 72689.5295   True
#     NC     PD -16102.1229 0.4569 -47996.8944 15792.6486  False
# --------------------------------------------------------------
# 3th Tukey HSD test positive -->> CortexVol
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
# group1 group2   meandiff  p-adj     lower      upper    reject
# --------------------------------------------------------------
#     ET     NC  51884.8173  0.001   23145.458 80624.1766   True
#     ET     PD  36111.6007 0.0062   8772.6586 63450.5427   True
#     NC     PD -15773.2166 0.3394 -42358.8748 10812.4415  False
# --------------------------------------------------------------
# 6th Tukey HSD test positive -->> CSF
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#     ET     NC -242.8114 0.0019  -407.341 -78.2819   True
#     ET     PD -209.9302 0.0053 -366.4425 -53.4179   True
#     NC     PD   32.8812 0.8502 -119.3186 185.0811  False
# --------------------------------------------------------
# 7th Tukey HSD test positive -->> 3rd_Ventricle
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
# group1 group2  meandiff p-adj    lower      upper   reject
# ----------------------------------------------------------
#     ET     NC -722.6526  0.001 -1115.1316 -330.1736   True
#     ET     PD -654.6801  0.001 -1028.0343 -281.3259   True
#     NC     PD   67.9725 0.8893  -295.0945  431.0395  False
# ----------------------------------------------------------
# 15th Tukey HSD test positive -->> Left_Inf_Lat_Vent
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
# group1 group2  meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------
#     ET     NC -328.8655 0.0015 -547.0167 -110.7143   True
#     ET     PD  -270.678  0.007 -478.1991  -63.1569   True
#     NC     PD   58.1875 0.7522 -143.6156  259.9906  False
# ---------------------------------------------------------
# 16th Tukey HSD test positive -->> Left_Lateral_Ventricle
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================
# group1 group2  meandiff  p-adj     lower      upper    reject
# -------------------------------------------------------------
#     ET     NC -8329.3114  0.001 -13415.6847 -3242.9382   True
#     ET     PD -6481.2377 0.0054 -11319.7611 -1642.7142   True
#     NC     PD  1848.0737 0.6105  -2857.1314  6553.2789  False
# -------------------------------------------------------------
# 20th Tukey HSD test positive -->> Left_Amygdala
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#     ET     NC 182.1445  0.007    42.364  321.925   True
#     ET     PD 136.8464 0.0422    3.8771 269.8157   True
#     NC     PD -45.2981 0.6681 -174.6036  84.0074  False
# -------------------------------------------------------
# 26th Tukey HSD test positive -->> Right_Inf_Lat_Vent
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
# group1 group2  meandiff p-adj   lower     upper   reject
# --------------------------------------------------------
#     ET     NC -442.6864 0.001 -676.4303 -208.9426   True
#     ET     PD -424.6502 0.001 -647.0041 -202.2962   True
#     NC     PD   18.0363   0.9 -198.1911  234.2636  False
# --------------------------------------------------------
# 27th Tukey HSD test positive -->> Right_Lateral_Ventricle
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================
# group1 group2  meandiff  p-adj     lower      upper    reject
# -------------------------------------------------------------
#     ET     NC -7257.9531  0.001 -11596.0841 -2919.8221   True
#     ET     PD  -5280.335 0.0083  -9407.0767 -1153.5933   True
#     NC     PD  1977.6181 0.4739  -2035.4173  5990.6536  False
# -------------------------------------------------------------
# 37th Tukey HSD test positive -->> Inf_Lat_Vent
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
# group1 group2  meandiff p-adj    lower      upper   reject
# ----------------------------------------------------------
#     ET     NC -771.5519  0.001 -1199.9794 -343.1244   True
#     ET     PD -695.3282  0.001 -1102.8792 -287.7772   True
#     NC     PD   76.2238 0.8824  -320.0978  472.5453  False
# ----------------------------------------------------------
# 38th Tukey HSD test positive -->> Lateral_Ventricle
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
# group1 group2   meandiff  p-adj     lower      upper    reject
# --------------------------------------------------------------
#     ET     NC -15587.2645  0.001 -24846.2462 -6328.2829   True
#     ET     PD -11761.5727 0.0056 -20569.3808 -2953.7646   True
#     NC     PD   3825.6919 0.5375  -4739.4302 12390.8139  False
# --------------------------------------------------------------
# All data Discovered diff:  11
# Diff features:  Index(['TotalGrayVol', 'CortexVol', 'CSF', '3rd_Ventricle',
#        'Left_Inf_Lat_Vent', 'Left_Lateral_Ventricle', 'Left_Amygdala',
#        'Right_Inf_Lat_Vent', 'Right_Lateral_Ventricle', 'Inf_Lat_Vent',
#        'Lateral_Ventricle'],
#       dtype='object')
# Screening 60-70 data raw:
# 60-70 Discovered diff:  0
# Diff features:  Index([], dtype='object')

# %%
# all_asr_data, stf_asr_data, all_data, stf_data
region_focus = ['TotalGrayVol', 'CortexVol', 'CSF', '3rd_Ventricle', 'Lateral_Ventricle', 'Inf_Lat_Vent'];
region_r_focus = [ x+'_r'for x in region_focus];
region_asr_focus = [ x+'_AgeSexRemoved_r'for x in region_focus];

t1=sns.pairplot(all_asr_data, vars=region_focus,  hue="diagnosis", markers=["o", "s", "D"],
                diag_kind="kde", height=5)
t1.map_lower(sns.kdeplot, levels=4, color=".2")

t2=sns.pairplot(all_asr_data, vars=region_r_focus,  hue="diagnosis", markers=["o", "s", "D"],
                diag_kind="kde", height=5)
t2.map_lower(sns.kdeplot, levels=4, color=".2")

t3=sns.pairplot(all_asr_data, vars=region_asr_focus,  hue="diagnosis", markers=["o", "s", "D"],
                diag_kind="kde", height=5)
t3.map_lower(sns.kdeplot, levels=4, color=".2")
# Out:
# /usr/local/miniconda/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/miniconda/lib/python3.7/site-packages/seaborn/distributions.py:1077: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/miniconda/lib/python3.7/site-packages/seaborn/distributions.py:1077: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/miniconda/lib/python3.7/site-packages/seaborn/distributions.py:1077: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/miniconda/lib/python3.7/site-packages/seaborn/distributions.py:1077: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/miniconda/lib/python3.7/site-packages/seaborn/distributions.py:1077: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# all_asr_data, stf_asr_data, all_data, stf_data
region_focus = ['TotalGrayVol', 'Right_Accumbens_area'];
region_r_focus = [ x+'_r'for x in region_focus];
region_asr_focus = [ x+'_AgeSexRemoved_r'for x in region_focus];
 
#t1=sns.pairplot(all_asr_data, vars=region_asr_focus,  hue="diagnosis", markers=["o", "s", "D"],
#                diag_kind="kde", height=5)
#t1.map_lower(sns.kdeplot, levels=4, color=".2")
g = sns.FacetGrid(all_asr_data, hue="diagnosis",  height=5)
g.map(sns.scatterplot, "age", "Right_Accumbens_area_AgeSexRemoved_r", s=100, alpha=.5)
g.add_legend()
g.set(ylim=(.0001, .0007))

g = sns.FacetGrid(stf_asr_data, hue="diagnosis",  height=5)
g.map(sns.scatterplot, "age", "Right_Accumbens_area_AgeSexRemoved_r", s=100, alpha=.5)
g.add_legend()
g.set(ylim=(.0001, .0007))
#g = sns.pairplot(all_asr_data, vars=region_asr_focus, hue="diagnosis", height=5)
#g.map_diag(sns.kdeplot)
#g.map_offdiag(sns.scatterplot)
#g.set(ylim=(0, .0007))
#g.add_legend()

# %%
list(all_asr_data['Right_Accumbens_area_AgeSexRemoved_r'])
# Out:
# [0.0004978016213605809,
#  0.0003977813965015933,
#  0.0005289057967096847,
#  0.0004595855272392896,
#  0.000380677281020714,
#  0.0004379292097396472,
#  0.0005054932028227689,
#  0.0005140802244941523,
#  0.00048173848425793416,
#  0.0004933794711200531,
#  0.0004268148956148825,
#  0.0004368917960472655,
#  0.00048542155806254554,
#  0.0005164795069679602,
#  0.0004215966647199044,
#  0.0004468402815682525,
#  0.00043888819315717923,
#  0.0005198961483613421,
#  0.00035777620867031055,
#  0.0004804623470441742,
#  0.0005260108096318518,
#  0.0003946408835308358,
#  0.00040332283542272884,
#  0.000382678679457361,
#  0.0004458292307639955,
#  0.00042379483715533406,
#  0.00042820119884706096,
#  0.0004874814938121562,
#  0.0005263098587641343,
#  0.0004709757082367193,
#  0.00045014269402476854,
#  0.00035453763888574084,
#  0.00047837409023388373,
#  0.0005202635347763936,
#  0.0004333532871122524,
#  0.0004364258912890993,
#  0.00040367627002542954,
#  0.00040946903679448595,
#  0.00047845297800228764,
#  0.00046191667110702926,
#  0.00040176029823776335,
#  0.0004932310142012406,
#  0.00044876110368951595,
#  0.0004348938468171322,
#  0.0004556594067545461,
#  0.0004594201324376394,
#  0.00039669079757988397,
#  0.00036879312460035533,
#  0.0005653842195763658,
#  0.000454557496099308,
#  0.000492590093304416,
#  0.0003997611636493495,
#  0.0004888553333263531,
#  0.000508170324342324,
#  0.0005122224489516821,
#  0.0004413954149240813,
#  0.00044159729238383986,
#  0.00036915194381134214,
#  0.0005198449906609007,
#  0.0004439645032324808,
#  0.00044076195375960674,
#  0.00046939164565311885,
#  0.0004690826413481789,
#  0.00040887573322425806,
#  0.0005140610162796813,
#  0.00046553762896264875,
#  0.0005348778006894017,
#  0.0005590503102268678,
#  0.0006398517421706643,
#  0.00048418363510071085,
#  0.0004846446737478528,
#  0.00039052822228842347,
#  0.000601951725840749,
#  0.0004528628730417331,
#  0.0004805601384580151,
#  0.0003320214355138946,
#  0.00046071806127906623,
#  0.0005419673867228541,
#  0.0003975600639637844,
#  0.0004062138015911773,
#  0.00048822362962051553,
#  0.00046347821941143186,
#  0.0004653179724487408,
#  0.0005026883255766407,
#  0.00048750978231723645,
#  0.0006122286928263756,
#  0.0005274927407326477,
#  0.000447917250384646,
#  0.0004441358310178636,
#  0.0005359091120909433,
#  0.00044585165830094304,
#  0.0005025367389974683,
#  0.0005454373047040297,
#  0.0004460416457921411,
#  0.0004220637810693247,
#  0.0005035275906793437,
#  0.0004970812609611369,
#  0.0004564131880846999,
#  0.00048462236431593894,
#  0.0004111891079751788,
#  0.0005059905788058807]
